# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = np.random.normal(100, 100, 100)

# %%
np.mean(X)
# Out:
# 89.19619693605077

# %%
np.std(X)
# Out:
# 95.36687072562252

# %%
plt.plot(X)
